# %% [markdown]
# <a href="https://colab.research.google.com/github/MeghanaDuddi37/Python-programs/blob/main/PYTHON_self.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=1
print(a)
# Out:
# 1

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
m=e=g=7
print(m)
print(e)
print(g)
# Out:
# 7
# 7
# 7

# %%
abc4343=3
print(id(abc4343))
# Out:
# 132060581822768

# %%
def reverse_string(str):
  if len(str)==0:
    return-1
  else:
    words=str.split()
    words.reverse()
    str=" ".join(words)
    return str
str=input()
print(reverse_string(str))
# Out:
# hgf hgk
# hgk hgf

# %% [markdown]
# REVERSE STRING

# %%
def reverse_string(str):
  if len(str)==0:
    return-1
  else:
     words=str.split()
     words.reverse()
     str=" ".join(words)
     return str
str=input()
print(reverse_string(str))
# Out:
# meghana duddi
# duddi meghana

# %% [markdown]
# RATS FOOD

# %%
def minimum_houses(r,unit,arr):
  if arr is None:
     return-1
  total_food_required=r*unit
  current_food=0
  for i in range(len(arr)):
    current_food+=arr[i]
    if current_food>=total_food_required:
      return i+1
      return 0
r=7
unit=2
n=8
arr=[2,8,3,5,7,4,1,2]
print(minimum_houses (r,unit,arr))
# Out:
# 4

# %% [markdown]
# CHARACTER REPLACEMENT

# %%
def replacecharacter(char_str,char_ch1,char_ch2):
  if len(char_str)==0:
    return -1
  else:
    char_str=char_str.replace(char_ch1,char_ch2)
    return char_str
char_str=input()
char_ch1=input()
char_ch2=input()
print(replacecharacter(char_str,char_ch1,char_ch2))
# Out:
# KANCHANA
# K
# V
# VANCHANA

# %%
def findCount(arr,  length, num, diff):
    count = 0
    for i in range(length):
        if abs(arr[i] - num) <= diff:
            count += 1
    return count if count > 0else -1

# Example usage:
arr = [12, 3, 14, 56, 77, 13]
num = 13
diff = 2
result = findCount(arr, len(arr), num, diff)
print(result)  # Output should be 3
# Out:
# 3

# %% [markdown]
# longest common subsequence

# %%
def longest_common_subsequence(X, Y):
    m = len(X)
    n = len(Y)


    L = [[0] * (n + 1) for i in range(m + 1)]


    for i in range(m + 1):
        for j in range(n + 1):
            if i == 0 or j == 0:
                L[i][j] = 0
            elif X[i-1] == Y[j-1]:
                L[i][j] = L[i-1][j-1] + 1
            else:
                L[i][j] = max(L[i-1][j], L[i][j-1])

    # L[m][n] contains the length of LCS for X[0..m-1], Y[0..n-1]
    return L[m][n]

# Example usage
X = "ABCBDAB"
Y = "BDCABA"
print(f"The length of the LCS is {longest_common_subsequence(X, Y)}")
# Out:
# The length of the LCS is 4

# %%
def findCount(arr, length, num, diff):
   count = 0
   for i in range(length):
    if abs(arr[i]-num)<=diff:
      count+=1
    return count if count>0else -1
arr=[12,3,14,56,77,13]
num=13
diff=2
result=findCount(arr, len(arr), num, diff)
print(result)
# Out:
# 1
